# %%
# -*- coding: UTF-8 -*-
"""PyRamen Homework Starter."""

# @TODO: Import libraries
import csv
from pathlib import Path

# @TODO: Set file paths for menu_data.csv and sales_data.csv
menu_filepath = Path('Resources/menu_data.csv')
sales_filepath = Path('Resources/sales_data.csv')

# @TODO: Initialize list objects to hold our menu and sales data
menu = []
sales = []

# @TODO: Read in the menu data into the menu list

# Open the input path as a file object
with open(menu_filepath, 'r') as menu_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    menu_reader = csv.reader(menu_file, delimiter=',')
    
    menu_header = next(menu_reader)

    for menu_row in menu_reader:

        # Set salary variable equal to the value in the 4th column of each row
        menu_item = str(menu_row[0])
        menu_price = float(menu_row[3])
        menu_cost = float(menu_row[4])
        # Append the row salary value to the list of salaries
        menu.append([menu_item,menu_price,menu_cost])

        # Print the row
    print(menu)

# @TODO: Read in the sales data into the sales list

# Open the input path as a file object
with open(sales_filepath, 'r') as sales_file:

    # Pass in the csv file to the csv.reader() function
    # (with ',' as the delmiter/separator) and return the csvreader object
    sales_reader = csv.reader(sales_file, delimiter=',')
    
    sales_header = next(sales_reader)

    for sales_row in sales_reader:

        # Set salary variable equal to the value in the 4th column of each row
        sales_date = str(sales_row[1])
        sales_quantity = int(sales_row[3])
        sales_item = str(sales_row[4])
        # Append the row salary value to the list of salaries
        sales.append({sales_item : sales_quantity})

        # Print the row
    print(sales)
    
# @TODO: Initialize dict object to hold our key-value pairs of items and metrics
report = {}

# Initialize a row counter variable
row_count = 0

# @TODO: Loop over every row in the sales list object




    # Line_Item_ID,Date,Credit_Card_Number,Quantity,Menu_Item
    # @TODO: Initialize sales data variables


    # @TODO:
    # If the item value not in the report, add it as a new entry with initialized metrics
    # Naming convention allows the keys to be ordered in logical fashion, count, revenue, cost, profit








    # @TODO: For every row in our sales data, loop over the menu records to determine a match


        # Item,Category,Description,Price,Cost
        # @TODO: Initialize menu data variables




        # @TODO: Calculate profit of each item in the menu data


        # @TODO: If the item value in our sales data is equal to the any of the items in the menu, then begin tracking metrics for that item


            # @TODO: Print out matching menu data






            # @TODO: Cumulatively add up the metrics for each item key





        # @TODO: Else, the sales item does not equal any fo the item in the menu data, therefore no match



    # @TODO: Increment the row counter by 1


# @TODO: Print total number of records in sales data




# @TODO: Write out report to a text file (won't appear on the command line output)
# Out:
# [['edamame', 4.0, 1.0], ['house salad', 4.0, 2.0], ['cucumber sunomono salad', 5.0, 2.0], ['hiyashi wakame seaweed salad', 5.0, 2.0], ['agedashi tofu', 5.0, 2.0], ['hiyayakko tofu', 5.0, 2.0], ['pork floss bao', 4.0, 2.0], ['kakuni bao', 6.0, 3.0], ['edamame fried gyoza (vegan)', 6.0, 3.0], ['fried gyoza', 6.0, 6.0], ['takoyaki', 6.0, 3.0], ['rock shrimp tempura', 6.0, 3.0], ['soft-shell crab tempura', 6.0, 3.0], ['ebi katsu shrimp bao', 6.0, 3.0], ['nagomi shoyu', 11.0, 5.0], ['shio ramen', 11.0, 5.0], ['spicy miso ramen', 12.0, 5.0], ['vegetarian spicy miso', 12.0, 5.0], ['miso crab ramen', 12.0, 6.0], ['soft-shell miso crab ramen', 14.0, 7.0], ['tori paitan ramen', 13.0, 6.0], ['tonkotsu ramen', 13.0, 6.0], ['burnt garlic tonkotsu ramen', 14.0, 6.0], ['vegetarian curry + king trumpet mushroom ramen', 13.0, 7.0], ['truffle butter ramen', 14.0, 7.0], ['green tea', 2.5, 1.0], ['coke', 2.0, 1.0], ['black sesame ice cream', 5.0, 2.0], ['matcha ice cream', 5.0, 2.0], ['mango mochi ice cream', 5.0, 2.0], ['strawberry mochi ice cream', 5.0, 2.0], ['black sesame creme brulee', 6.0, 3.0]]
# [{'spicy miso ramen': 1}, {'spicy miso ramen': 1}, {'tori paitan ramen': 3}, {'tori paitan ramen': 3}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'tonkotsu ramen': 1}, {'tonkotsu ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'shio ramen': 1}, {'shio ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'spicy miso ramen': 1}, {'spicy miso ramen': 1}, {'truffle butter ramen': 2}, {'truffle butter ramen': 2}, {'tonkotsu ramen': 2}, {'tonkotsu ramen': 2}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'tori paitan ramen': 2}, {'tori paitan ramen': 2}, {'spicy miso ramen': 1}, {'spicy miso ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'tonkotsu ramen': 4}, {'tonkotsu ramen': 4}, {'miso crab ramen': 4}, {'miso crab ramen': 4}, {'miso crab ramen': 1}, {'miso crab ramen': 1}, {'nagomi shoyu': 1}, {'nagomi shoyu': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'soft-shell miso crab ramen': 1}, {'soft-shell miso crab ramen': 1}, {'nagomi shoyu': 3}, {'nagomi shoyu': 3}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'shio ramen': 1}, {'shio ramen': 1}, {'nagomi shoyu': 2}, {'nagomi shoyu': 2}, {'soft-shell miso crab ramen': 1}, {'soft-shell miso crab ramen': 1}, {'tonkotsu ramen': 1}, {'tonkotsu ramen': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'spicy miso ramen': 1}, {'spicy miso ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'soft-shell miso crab ramen': 2}, {'soft-shell miso crab ramen': 2}, {'spicy miso ramen': 4}, {'spicy miso ramen': 4}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'burnt garlic tonkotsu ramen': 3}, {'burnt garlic tonkotsu ramen': 3}, {'miso crab ramen': 4}, {'miso crab ramen': 4}, {'truffle butter ramen': 3}, {'truffle butter ramen': 3}, {'vegetarian spicy miso': 3}, {'vegetarian spicy miso': 3}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'tonkotsu ramen': 1}, {'tonkotsu ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'tonkotsu ramen': 1}, {'tonkotsu ramen': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'truffle butter ramen': 3}, {'truffle butter ramen': 3}, {'nagomi shoyu': 1}, {'nagomi shoyu': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'spicy miso ramen': 1}, {'spicy miso ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'tori paitan ramen': 1}, {'vegetarian spicy miso': 2}, {'vegetarian spicy miso': 2}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'vegetarian curry + king trumpet mushroom ramen': 1}, {'nagomi shoyu': 1}, {'nagomi shoyu': 1}, {'nagomi shoyu': 4}, {'nagomi shoyu': 4}, {'burnt garlic tonkotsu ramen': 1}, {'burnt garlic tonkotsu ramen': 1}, {'nagomi shoyu': 1}, {'nagomi shoyu': 1}, {'vegetarian spicy miso': 1}, {'vegetarian spicy miso': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'truffle butter ramen': 1}, {'shio ramen': 1}, {'shio ramen': 1}, {'vegetarian cu ...
